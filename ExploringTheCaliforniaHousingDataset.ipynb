# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing_data = pd.read_csv('datasets/housing.csv')
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19886    -119.13     36.30                33.0       3379.0           612.0
# 4548     -118.21     34.02                52.0         22.0             7.0
# 9165     -118.43     34.42                13.0       3600.0           580.0
# 9160     -118.49     34.43                15.0       8244.0          1409.0
# 14046    -117.13     32.77                30.0       2582.0           650.0
#
#        population  households  median_income  median_house_value  \
# 19886      1565.0       618.0         2.7321             76500.0
# 4548         55.0         7.0         7.5752             67500.0
# 9165       1799.0       576.0         6.2971            218300.0
# 9160       4453.0      1357.0         5.4829            199600.0
# 14046      1098.0       603.0         2.8281            171700.0
#
#       ocean_proximity
# 19886          INLAND
# 4548        <1H OCEAN
# 9165        <1H OCEAN
# 9160        <1H OCEAN
# ...

# %%
housing_data.shape
# Out:
# (20640, 10)

# %%
housing_data.dropna(inplace=True)

# %%
housing_data.shape
# Out:
# (20433, 10)

# %%
housing_data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
fig, ax = plt.subplots(figsize=(12, 8))

_ = plt.scatter(housing_data['total_rooms'], housing_data['median_house_value'])
_ = plt.xlabel('Total Rooms')
_ = plt.ylabel('Median House Price')

# %%
fig, ax = plt.subplots(figsize=(12,8))
_ = plt.scatter(housing_data['housing_median_age'], housing_data['median_house_value'])
_ = plt.xlabel('Median Age')
_ = plt.ylabel('Median Value')

# %%
housing_data_corr = housing_data.corr()
housing_data_corr
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.100270 -0.108997           -0.295787     0.857281
# households           0.056513 -0.071774           -0.302768     0.918992
# median_income       -0.015550 -0.079626           -0.118278     0.197882
# median_house_value  -0.045398 -0.144638            0.106432     0.133294
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.100270    0.056513      -0.015550
# latitude                 -0.066983   -0.108997   -0.071774      -0.079626
# ...

# %%
fir, ax = plt.subplots(figsize=(12,10))

sns.heatmap(housing_data_corr, annot=True)
